# %% [markdown]
# # Supervised Learning Models
# SIADS 696 Milestone II - Summer 2026
# BRFSS 2024 · Predicting `_MICHD`
# **Maria Febus**

# %% [markdown]
# ## **1. Setup & Imports**
# Libraries, package installs

# %%
# (If using Google Colab, the repo can be clone as specified below:)
# %cd /content
# !git clone https://github.com/ALEE0001/model_myocardial_infarction.git
# %cd model_myocardial_infarction
# !git pull

# %%
# !pip install xgboost==3.2.0
# Out:
# Requirement already satisfied: xgboost==3.2.0 in c:\users\18327\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\18327\anaconda3\lib\site-packages (from xgboost==3.2.0) (1.26.4)
# Requirement already satisfied: scipy in c:\users\18327\anaconda3\lib\site-packages (from xgboost==3.2.0) (1.15.3)

# %%
# %pip install "scikit-learn==1.5.2" "imbalanced-learn==0.12.4"
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, sys

# Project paths
if os.path.basename(os.getcwd()) == "notebook":
    _PROJECT_ROOT = os.path.dirname(os.getcwd())
elif os.path.isdir(os.path.join(os.getcwd(), "utilities")):
    _PROJECT_ROOT = os.getcwd()
else:
    raise FileNotFoundError(
        "Cannot find project root. Run from the project root or notebook/ directory."
    )

DATA_DIR = os.path.join(_PROJECT_ROOT, "data")
UTIL_DIR  = os.path.join(_PROJECT_ROOT, "utilities")
VIZ_DIR  = os.path.join(_PROJECT_ROOT, "visualization")

sys.path.insert(0, UTIL_DIR)

# brfss_utils - data loading, display labels, EDA helpers
from brfss_utils import (
    RANDOM_STATE, CV_FOLDS, TARGET,
    LABELS, AGE_LABELS, humanize,
    load_data, find_missingness_drivers, outlier_summary,
)

# model_pipeline - modeling machinery (params, pipeline, ablation, sensitivity)
from model_pipeline import (
    LR_PARAMS, RF_PARAMS, XGB_PARAMS,
    make_preprocessor, build_pipeline, train_pipeline,
    evaluate_pipeline, plot_dashboard, run_model,
    ablate_one, run_ablation, run_ablation_groups, sensitivity_min_samples_leaf,
)

# viz - all figures (EDA, SHAP, sensitivity, failure analysis)
from viz import (
    plot_outlier_boxplot, plot_age_health_interaction, plot_mi_by_comorbidity,
    plot_shap_beeswarm, plot_sensitivity,
    select_failure_records, print_failure_records, plot_failure_by_age,
)

# Third-party libs still needed directly in the notebook
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import recall_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold, cross_val_score

pd.set_option("display.html.table_schema", False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[44], line 27
#      20 from brfss_utils import (
#      21     RANDOM_STATE, CV_FOLDS, TARGET,
#      22     LABELS, AGE_LABELS, humanize,
#      23     load_data, find_missingness_drivers, outlier_summary,
#      24 )
#      26 # model_pipeline - modeling machinery (params, pipeline, ablation, sensitivity)
# ---> 27 from model_pipeline import (
#      28     LR_PARAMS, RF_PARAMS, XGB_PARAMS,
#      29     make_preprocessor, build_pipeline, train_pipeline,
#      30     evaluate_pipeline, plot_dashboard, run_model,
#      31     ablate_one, run_ablation, run_ablation_groups, sensitivity_min_samples_leaf,
#      32 )
#      34 # viz - all figures (EDA, SHAP, sensitivity, failure analysis)
#      35 from viz import (
#      36     plot_outlier_boxplot, plot_age_health_interaction, plot_mi_by_comorbidity,
#      37     plot_shap_beeswarm, plot_sensitivity,
#      38     select_failure_records, print_failure_records, plot_failure_by_age,
#      39 )
#
# ImportError: cannot import name 'run_ablation_groups' from 'model_pipeline' (c:\Users\18327\Desktop\Python Projects\model_myocardial_infarction\src\model_pipeline.py)

# %% [markdown]
# ## **2. Constants**
# `RANDOM_STATE`, `CV_FOLDS`, `TARGET`, and model parameter dicts.

# %%
# Constants and model-parameter dicts defined in 
# brfss_utils and model_pipeline scripts
#   RANDOM_STATE, CV_FOLDS, TARGET            
#   LR_PARAMS, RF_PARAMS, XGB_PARAMS          
# Shown here for reference.
print("RANDOM_STATE:", RANDOM_STATE, "| CV_FOLDS:", CV_FOLDS, "| TARGET:", TARGET)
print("LR_PARAMS:", LR_PARAMS)
print("RF_PARAMS:", RF_PARAMS)
print("XGB_PARAMS:", XGB_PARAMS)
# Out:
# RANDOM_STATE: 42 | CV_FOLDS: 5 | TARGET: _MICHD
# LR_PARAMS: {'max_iter': 1000, 'random_state': 42}
# RF_PARAMS: {'n_estimators': 1000, 'max_depth': None, 'min_samples_leaf': 20, 'random_state': 42, 'n_jobs': -1}
# XGB_PARAMS: {'eval_metric': 'logloss', 'random_state': 42}

# %% [markdown]
# ## **3. Helpers**
# Display labels (`LABELS`, `humanize()`) and small reusable functions.
# *Defined here so every cell below can use them.*

# %%
# Display labels (LABELS, AGE_LABELS) and humanize() now live in
# brfss_utils and were imported above. 
print(humanize("_AGEG5YR"))                 # -> "Age group"
print(humanize("_RFHLTH_Fair or Poor Health"))  # -> "General health = ..."
# Out:
# Age group
# General health = Fair or Poor Health

# %% [markdown]
# ## **4. Data Loading & Initial Dataset Inspection**
# Load dataset and `selected_features.pkl`; define `cat_features` / `cont_features`

# %%
DATA_PATH     = os.path.join(DATA_DIR, "processed_data.csv")
FEATURES_PATH = os.path.join(DATA_DIR, "selected_features.pkl")

data = load_data(DATA_PATH, FEATURES_PATH)

df               = data["df"]
FEATURES         = data["FEATURES"]
categorical_cols = data["categorical_cols"]
continuous_cols  = data["continuous_cols"]
cat_features     = data["cat_features"]
cont_features    = data["cont_features"]

print(f"Entire dataset (processed_data)\n"
      f"-categorical: {len(categorical_cols)}\n"
      f"-continuous: {len(continuous_cols)}")
# Out:
# Entire dataset (processed_data)
# -categorical: 58
# -continuous: 14

# %%
# Check dataframe shape. This is the entire dataframe prior to filtering the selected features

print("Entire dataset (including target variable): ",df.shape)
# Out:
# Entire dataset (including target variable):  (452464, 73)

# %%
# From this point onward the df dataframe now contains only the selected features plus the target variable

df = df[FEATURES + [TARGET]].copy()
df.head()
# Out:
#    _ismale   CHECKUP1  _TOTINDA  _LCSYQTS DIFFDRES CHCOCNC1  \
# 0        0   Within 1       1.0       NaN       No       No
# 1        1   Within 1       1.0      53.0       No       No
# 2        1  5 or more       1.0       NaN       No       No
# 3        1   Within 1       1.0       NaN       No       No
# 4        1   Within 1       0.0       NaN       No       No
#
#                _INCOMG1 VETERAN3 DIFFALON         _SMOKER3  ... HAVARTH4  \
# 0               Unknown       No       No       Non Smoker  ...      Yes
# 1      $200,000 or more      Yes       No    Former Smoker  ...      Yes
# 2               Unknown      Yes       No  Everyday Smoker  ...      Yes
# 3  $35,000 to < $50,000       No       No       Non Smoker  ...      Yes
# 4  $15,000 to < $25,000       No      Yes       Non Smoker  ...       No
#
#    PHYSHLTH     DIABETE4 CHCCOPD3                PRIMINS2 CVDSTRK3 DIFFWALK  \
# 0       2.0  No Diabetes       No                Medicare       No       No
# 1       NaN  No Diabetes       No                Medicare       No       No
# 2      30.0  No Diabetes       No  Employer or union plan       No       No
# 3       NaN  No Diabetes       No                Medicare       No       No
# 4       NaN  No Diabetes       No                Medicaid       No      Yes
#
#                  _RFHLTH  _AGEG5YR _MICHD
# 0  Good or Better Health      12.0    0.0
# 1  Good or Better Health      13.0    1.0
# 2  Good or Better Health       8.0    0.0
# 3  Good or Better Health      13.0    0.0
# 4  Good or Better Health       6.0    0.0
#
# [5 rows x 29 columns]

# %%
# cat_features / cont_features were already built by load_data() above
# (mirrors the EDA notebook's logic). Shown here for reference.
print("categorical features:", len(cat_features))
print("continuous features: ", len(cont_features))
# Out:
# categorical features: 22
# continuous features:  6

# %%
df.columns
# Out:
# Index(['_ismale', 'CHECKUP1', '_TOTINDA', '_LCSYQTS', 'DIFFDRES', 'CHCOCNC1',
#        '_INCOMG1', 'VETERAN3', 'DIFFALON', '_SMOKER3', 'PREGNANT', 'LCSNUMCG',
#        'PERSDOC3', 'DEAF', 'MARITAL', 'PNEUVAC4', 'CHCKDNY2', '_LCSYSMK',
#        'POORHLTH', 'HAVARTH4', 'PHYSHLTH', 'DIABETE4', 'CHCCOPD3', 'PRIMINS2',
#        'CVDSTRK3', 'DIFFWALK', '_RFHLTH', '_AGEG5YR', '_MICHD'],
#       dtype='object')

# %%
df.shape
# Out:
# (452464, 29)

# %%
# Data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452464 entries, 0 to 452463
# Data columns (total 29 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   _ismale   452464 non-null  int64
#  1   CHECKUP1  452464 non-null  object
#  2   _TOTINDA  451270 non-null  float64
#  3   _LCSYQTS  119217 non-null  float64
#  4   DIFFDRES  452464 non-null  object
#  5   CHCOCNC1  452464 non-null  object
#  6   _INCOMG1  452464 non-null  object
#  7   VETERAN3  452464 non-null  object
#  8   DIFFALON  452464 non-null  object
#  9   _SMOKER3  452464 non-null  object
#  10  PREGNANT  452464 non-null  object
#  11  LCSNUMCG  150795 non-null  float64
#  12  PERSDOC3  452464 non-null  object
#  13  DEAF      452464 non-null  object
#  14  MARITAL   452464 non-null  object
#  15  PNEUVAC4  452464 non-null  object
#  16  CHCKDNY2  452464 non-null  object
#  17  _LCSYSMK  149871 non-null  float64
#  18  POORHLTH  124272 non-null  float64
#  19  HAVARTH4  452464 non-null  object
#  20  PHYSHLTH  176477 non-null  float64
#  21  DIABETE4  452464 non-null  object
#  22  CHCCOPD3  452464 non-null  object
#  23  PRIMINS2  452464 non-null  object
#  24  CVDSTRK3  452464 non-null  object
#  25  DIFFWALK  452464 non-null  object
#  26  _RFHLTH   452464 non-null  object
#  27  _AGEG5YR  452464 non-null  float64
#  28  _MICHD    452464 non-null  float64
# dtypes: float64(8), int64(1), object(20)
# memory usage: 100.1+ MB

# %%
# Summary statistics of continuous features (mean, std, min, quartiles, max)

df[cont_features].describe().T
# Out:
#              count       mean        std   min   25%   50%   75%    max
# _LCSYQTS  119217.0  21.869280  17.479259 -30.0   6.0  19.0  36.0   83.0
# LCSNUMCG  150795.0  15.047581  12.402441   1.0   7.0  10.0  20.0  490.0
# _LCSYSMK  149871.0  24.402473  16.445062   0.0  10.0  22.0  37.0   90.0
# POORHLTH  124272.0  11.286991  10.273144   1.0   3.0   7.0  20.0   30.0
# PHYSHLTH  176477.0  11.432430  10.920214   1.0   2.0   6.0  20.0   30.0
# _AGEG5YR  452464.0   7.764786   3.735420   1.0   5.0   8.0  11.0   14.0

# %% [markdown]
# ## **5. Exploratory Data Analysis on Selected Features**

# %% [markdown]
# ### Missingness

# %%
# Check for missing values

df.isnull().sum()/len(df)*100
# Out:
# _ismale      0.000000
# CHECKUP1     0.000000
# _TOTINDA     0.263888
# _LCSYQTS    73.651605
# DIFFDRES     0.000000
# CHCOCNC1     0.000000
# _INCOMG1     0.000000
# VETERAN3     0.000000
# DIFFALON     0.000000
# _SMOKER3     0.000000
# PREGNANT     0.000000
# LCSNUMCG    66.672487
# PERSDOC3     0.000000
# DEAF         0.000000
# MARITAL      0.000000
# PNEUVAC4     0.000000
# CHCKDNY2     0.000000
# _LCSYSMK    66.876702
# POORHLTH    72.534389
# HAVARTH4     0.000000
# PHYSHLTH    60.996455
# DIABETE4     0.000000
# CHCCOPD3     0.000000
# PRIMINS2     0.000000
# CVDSTRK3     0.000000
# DIFFWALK     0.000000
# _RFHLTH      0.000000
# _AGEG5YR     0.000000
# _MICHD       0.000000
# dtype: float64

# %%
# Identify features over 10% missing and whether missingness is
# structural or random  (brfss_utils.find_missingness_drivers)
drivers = find_missingness_drivers(df)
print(drivers[["feature", "pct_missing", "top_driver", "driver_spread", "verdict"]].to_string(index=False))
# Out:
#  feature  pct_missing top_driver  driver_spread    verdict
# _LCSYQTS         73.7   _SMOKER3          0.909 STRUCTURAL
# POORHLTH         72.5   DIFFDRES          0.479      check
# _LCSYSMK         66.9   _SMOKER3          0.961 STRUCTURAL
# LCSNUMCG         66.7   _SMOKER3          0.961 STRUCTURAL
# PHYSHLTH         61.0   DIFFDRES          0.464      check

# %% [markdown]
# ### Observations:
# Three of the five high-missing features, the smoking-screen variables (_LCSYQTS, _LCSYSMK, LCSNUMCG), are confirmed STRUCTURAL, each driven by smoking status (_SMOKER3) with a driver spread above 0.90, meaning they are blank by survey design rather than at random. The two health-days features (POORHLTH, PHYSHLTH) show weaker spreads (~0.46–0.48) flagged as "check," indicating their missingness is only partly explained and warrants closer review before imputation.

# %% [markdown]
# ### Outliers

# %%
# IQR outlier counts and bounds per continuous feature
# (brfss_utils.outlier_summary)
outlier_tbl = outlier_summary(df, cont_features)
print(outlier_tbl.to_string(index=False))
# Out:
#  feature  n_outliers  pct_outliers  lower_bound  upper_bound
# LCSNUMCG        9572           6.3        -12.5         39.5
# _LCSYQTS           1           0.0        -39.0         81.0
# _LCSYSMK          24           0.0        -30.5         77.5
# POORHLTH           0           0.0        -22.5         45.5
# PHYSHLTH           0           0.0        -25.0         47.0
# _AGEG5YR           0           0.0         -4.0         20.0

# %%
# Boxplot of the smoking-screen continuous features  (viz.plot_outlier_boxplot)
plot_outlier_boxplot(df, savepath=os.path.join(VIZ_DIR, "eda_outlier_boxplot.png"))

# %% [markdown]
# ### Observations:
# All three smoking-screen features are heavily right-skewed, with their boxes compressed near the low end and long tails of high values flagged as outliers. The pattern is most extreme for cigarettes per day (LCSNUMCG), where a dense cluster of points stretches well above the upper fence. Because Alex's preprocessing has already recoded BRFSS sentinel values, these represent genuine high self-reported smoking volumes rather than coded artifacts. No outlier treatment is applied: the skew reflects the real shape of the data, and the selected Random Forest is robust to extreme values.

# %% [markdown]
# ### Multivariate Analysis

# %%
# MI rate across age group x general health  (viz.plot_age_health_interaction)
plot_age_health_interaction(df, savepath=os.path.join(VIZ_DIR, "eda_age_health_interaction.png"))

# %% [markdown]
# ### Observations:
# MI risk rises sharply with both age and poor health, climbing from under 1% for young, healthy respondents to over 35% for the oldest in fair/poor health.
# The two factors compound, being both old and in poor health stacks risk far higher than either alone (the darkest cells are bottom-left).
# The "old but healthy" cells sit in the middle, moderate risk where age and health pull in opposite directions, which is exactly the conflicting-signal zone that produces the model's borderline failures, as seen later in the notebook.

# %%
# MI rate among people with each individual comorbidity  (viz.plot_mi_by_comorbidity)
plot_mi_by_comorbidity(df, savepath=os.path.join(VIZ_DIR, "eda_mi_by_condition.png"))

# %% [markdown]
# ### Observations:
# Every chronic condition raises MI risk above the population baseline, with stroke history the strongest single marker at nearly four times the overall rate.
# Every comorbidity raises MI risk above the 9.4% baseline, all five bars sit well to the right of the dashed overall-rate line.
# Stroke history is the strongest single marker (~36%), nearly 4× the baseline, followed by kidney disease (~29%) and COPD (~27%), consistent with the ablation finding that stroke is the model's most irreplaceable feature, as seen later in the notebook.
# Arthritis carries the lowest elevated risk (16%), reflecting its weaker cardiovascular link compared to the metabolic and vascular conditions above it.

# %% [markdown]
# ## **6. Modeling Functions**
# Modular, reusable functions for the modeling pipeline. Each model family
# is trained through the same flow: build a preprocessor, assemble the
# pipeline, undersample and fit, evaluate with cross-validation, and plot
# results. `run_model` orchestrates the full sequence.

# %%
# All modeling functions now live in model_pipeline.py and were imported
# in the setup cell:
#   make_preprocessor, build_pipeline, train_pipeline,
#   evaluate_pipeline, plot_dashboard, run_model
# The train/test split is created here in the notebook so every section
# below shares the same X_train / X_test / y_train / y_test.
from sklearn.model_selection import train_test_split

X = df[FEATURES]   # the 27 selected features
y = df[TARGET]     # binary MI target

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,        # 80% train / 20% test
    stratify=y,           # preserve the ~9% MI rate in both splits
    random_state=RANDOM_STATE,
)
print("train:", X_train.shape, "| test:", X_test.shape)
# Out:
# train: (361971, 28) | test: (90493, 28)

# %% [markdown]
# ## **7. Train Models & Compare**
# Train Logistic Regression, Random Forest, XGBoost; build the comparison table.

# %% [markdown]
# ### Logistic Regression

# %%
results = {}
results["lr"] = run_model(
    LogisticRegression(**LR_PARAMS), "Logistic Regression",
    X_train, y_train, X_test, y_test, cat_features, cont_features,
)
# Out:
# === Logistic Regression ===
# CV AUC (5-fold): 0.8374 ± 0.0039
# Test AUC: 0.8377 | Test AP: 0.3624
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.75      0.84     82025
#          1.0       0.24      0.77      0.37      8468
#
#     accuracy                           0.75     90493
#    macro avg       0.60      0.76      0.60     90493
# weighted avg       0.90      0.75      0.80     90493
# c:\Users\18327\Desktop\Python Projects\model_myocardial_infarction\src\model_pipeline.py:281: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### Random Forest

# %%
results["rf"] = run_model(
    RandomForestClassifier(**RF_PARAMS), "Random Forest",
    X_train, y_train, X_test, y_test, cat_features, cont_features,
)
results_rf = results["rf"]
# Out:
# === Random Forest ===
# CV AUC (5-fold): 0.8386 ± 0.0040
# Test AUC: 0.8398 | Test AP: 0.3602
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.72      0.83     82025
#          1.0       0.23      0.81      0.36      8468
#
#     accuracy                           0.72     90493
#    macro avg       0.60      0.76      0.59     90493
# weighted avg       0.90      0.72      0.78     90493
# c:\Users\18327\Desktop\Python Projects\model_myocardial_infarction\src\model_pipeline.py:281: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### XGBoost

# %%
results["xgb"] = run_model(
    XGBClassifier(**XGB_PARAMS), "XGBoost",
    X_train, y_train, X_test, y_test, cat_features, cont_features,
)
# Out:
# === XGBoost ===
# CV AUC (5-fold): 0.8339 ± 0.0044
# Test AUC: 0.8364 | Test AP: 0.3400
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.73      0.83     82025
#          1.0       0.23      0.80      0.36      8468
#
#     accuracy                           0.73     90493
#    macro avg       0.60      0.76      0.60     90493
# weighted avg       0.90      0.73      0.79     90493
# c:\Users\18327\Desktop\Python Projects\model_myocardial_infarction\src\model_pipeline.py:281: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### Model Comparison

# %%
comparison = pd.DataFrame([
    {
        "Model":     r["name"],
        "CV AUC":    round(r["cv_auc_mean"], 4),
        "Test AUC":  round(r["test_auc"], 4),
        "Test AP":   round(r["test_ap"], 4),
        "MI Recall": round(recall_score(y_test, r["y_pred"], pos_label=1), 4),
    }
    for r in results.values()
]).sort_values("Test AUC", ascending=False)

print(comparison.to_string(index=False))
# Out:
#               Model  CV AUC  Test AUC  Test AP  MI Recall
#       Random Forest  0.8386    0.8398   0.3602     0.8115
# Logistic Regression  0.8374    0.8377   0.3624     0.7736
#             XGBoost  0.8339    0.8364   0.3400     0.7956

# %% [markdown]
# ### Observations:
# The three model families achieved very similar performance, with test ROC-AUC values ranging from 0.834 to 0.839, suggesting that model choice was not the primary factor limiting predictive performance. Instead, the available features appear to contain most of the predictive information that all three algorithms could exploit. Random Forest was selected as the final model because it achieved both the highest recall for the MI class (0.81), the primary metric for this screening application, and the highest overall test AUC (0.839). Logistic Regression performed nearly as well and achieved a slightly higher Average Precision (0.362), while offering the advantage of full interpretability. The comparable performance of the linear and tree-based models suggests that the predictive relationships in the data are captured reasonably well by all three approaches, with limited additional benefit from the more complex ensemble methods. Average Precision remained relatively low across all models (approximately 0.34–0.36), but considering the baseline is 0.094, the model is still relatively effective compared to random chance.

# %% [markdown]
# ## **7. In-Depth Analysis (Random Forest)**
# Feature importance (SHAP beeswarm), ablation, sensitivity, and failure mode

# %% [markdown]
# ### Feature Importance

# %%
# Global SHAP feature importance for the Random Forest  (viz.plot_shap_beeswarm)
plot_shap_beeswarm(results["rf"], X_test, savepath=os.path.join(VIZ_DIR, "shap_beeswarm.png"))

# %% [markdown]
# ### Observations:
# Age group is the model's dominant predictor: older respondents (red) are pushed toward an MI prediction, younger ones (blue) away from it. General health follows the same clinically sensible pattern - fair or poor health raises the predicted risk, while good health lowers it. The next tier is a cluster of comorbidity and healthcare-engagement features (diabetes, arthritis, having a personal doctor, pneumonia vaccination), each contributing modestly. Primary insurance also ranks highly, largely as an age proxy, since Medicare eligibility begins at 65 and overlaps with the age signal. Overall, the model behaves as an age-and-health risk predictor, which both explains its strong recall and sets up its characteristic failures where those signals mislead.

# %% [markdown]
# ## Feature Ablation

# %%
# Single-feature ablation: retrain the RF with each feature removed and
# rank by AUC impact  (model_pipeline.run_ablation)
ablation_feat_df = run_ablation(
    X_train, y_train, X_test, y_test, cat_features, cont_features,
)
print("\n=== Single-feature ablation, ranked by impact ===")
print(ablation_feat_df.to_string(index=False))
# Out:
# Baseline — full model: CV 0.8386 | Test 0.8398
#   removed _ismale       Test AUC 0.8323  ΔAUC -0.0075
#   removed CHECKUP1      Test AUC 0.8396  ΔAUC -0.0002
#   removed _TOTINDA      Test AUC 0.8399  ΔAUC +0.0001

# %% [markdown]
# ### Observations:
# Removing features one at a time shows that the model relies on a small handful of strong clinical predictors. Stroke history is the single most impactful feature, its removal causes the largest AUC drop (−0.0068), followed by age (−0.0055) and general health (−0.0051). Notably, although SHAP ranks age as the most important feature, ablation ranks stroke as the most irreplaceable: age has correlated proxies (Medicare, comorbidities) that substitute when it is removed, whereas stroke carries unique signal no other feature can replace. Beyond the top few predictors, the model is remarkably robust, removing almost any single remaining feature leaves AUC essentially unchanged, and a few even improve it marginally, indicating they add little signal. This concentration of predictive power in a few features is consistent with the model operating near the information ceiling of the available data.

# %% [markdown]
# ### Feature Category Ablation

# %%
FEATURE_GROUPS = {
    "Demographics":           ["_ismale", "_AGEG5YR", "MARITAL", "VETERAN3", "PREGNANT"],
    "Socioeconomic":          ["_INCOMG1", "PRIMINS2"],
    "Health Status":          ["_RFHLTH", "PHYSHLTH", "POORHLTH"],
    "Cardiovascular":         ["CVDSTRK3"],
    "Diabetes":               ["DIABETE4"],
    "Smoking":                ["_SMOKER3", "LCSNUMCG", "_LCSYSMK", "_LCSYQTS"],
    "Comorbidities":          ["CHCCOPD3", "CHCKDNY2", "HAVARTH4", "CHCOCNC1"],
    "Functional Limitations": ["DEAF", "DIFFWALK", "DIFFDRES", "DIFFALON"],
    "Healthcare Access":      ["PERSDOC3", "CHECKUP1"],
    "Preventive Care":        ["PNEUVAC4"],
    "Treatment":              ["_TOTINDA"],
}

ablation_group_df = run_ablation_groups(
    X_train, y_train, X_test, y_test, cat_features, cont_features)
print("\n=== Group ablation, ranked by impact ===")
print(ablation_group_df.to_string(index=False))
# Out:
# Baseline — full model: CV 0.8386 | Test 0.8398
#
#   removed Demographics              (5 feats)  Test AUC 0.8208  ΔAUC -0.0190
#   removed Socioeconomic             (2 feats)  Test AUC 0.8393  ΔAUC -0.0005
#   removed Health Status             (3 feats)  Test AUC 0.8337  ΔAUC -0.0061
#   removed Cardiovascular            (1 feats)  Test AUC 0.8334  ΔAUC -0.0064
#   removed Diabetes                  (1 feats)  Test AUC 0.8378  ΔAUC -0.0020
#   removed Smoking                   (4 feats)  Test AUC 0.8378  ΔAUC -0.0020
#   removed Comorbidities             (4 feats)  Test AUC 0.8353  ΔAUC -0.0045
#   removed Functional Limitations    (4 feats)  Test AUC 0.8390  ΔAUC -0.0008
#   removed Healthcare Access         (2 feats)  Test AUC 0.8359  ΔAUC -0.0038
#   removed Preventive Care           (1 feats)  Test AUC 0.8394  ΔAUC -0.0004
#   removed Treatment                 (1 feats)  Test AUC 0.8399  ΔAUC +0.0001
#
# === Group ablation, ranked by impact ===
#                  group  n_removed                               features_removed  cv_auc  test_auc  delta_auc
#           Demographics          5 _ismale, _AGEG5YR, MARITAL, VETERAN3, PREGNANT  0.8191    0.8208    -0.0190
#         Cardiovascular          1                                       CVDSTRK3  0.8326    0.8334    -0.0064
#          Health Status          3                    _RFHLTH, PHYSHLTH, POORHLTH  0.8337    0.8337    -0.0061
#          Comorbidities          4         CHCCOPD3, CHCKDNY2, HAVARTH4, CHCOCNC1  0.8337    0.8353    -0.0045
#      Healthcare Access          2                             PERSDOC3, CHECKUP1  0.8345    0.8359    -0.0038
#                Smoking          4         _SMOKER3, LCSNUMCG, _LCSYSMK, _LCSYQTS  0.8366    0.8378    -0.0020
#               Diabetes          1                                       DIABETE4  0.8367    0.8378    -0.0020
# Functional Limitations          4             DEAF, DIFFWALK, DIFFDRES, DIFFALON  0.8381    0.8390    -0.0008
#          Socioeconomic          2                             _INCOMG1, PRIMINS2  0.8378    0.8393    -0.0005
#        Preventive Care          1                                       PNEUVAC4  0.8383    0.8394    -0.0004
#              Treatment          1                                       _TOTINDA  0.8387    0.8399     0.0001

# %% [markdown]
# ## Sensitivity Analysis - Random Forest

# %%
# Sweep min_samples_leaf, then plot CV-AUC stability
# (model_pipeline.sensitivity_min_samples_leaf -> viz.plot_sensitivity)
sens_res = sensitivity_min_samples_leaf(
    X_train, y_train, cat_features, cont_features,
)
print(sens_res)

plot_sensitivity(sens_res, selected=RF_PARAMS["min_samples_leaf"], savepath=os.path.join(VIZ_DIR, "sensitivity_min_samples_leaf.png"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 3
#       1 # Sweep min_samples_leaf, then plot CV-AUC stability
#       2 # (model_pipeline.sensitivity_min_samples_leaf -> viz.plot_sensitivity)
# ----> 3 sens_res = sensitivity_min_samples_leaf(
#       4     X_train, y_train, cat_features, cont_features,
#       5 )
#       6 print(sens_res)
#       8 plot_sensitivity(sens_res, selected=RF_PARAMS["min_samples_leaf"], savepath=os.path.join(VIZ_DIR, "sensitivity_min_samples_leaf.png"))
#
# File c:\Users\18327\Desktop\Python Projects\model_myocardial_infarction\src\model_pipeline.py:416, in sensitivity_min_samples_leaf(X_train, y_train, cat_features, cont_features, param_values)
#     410 param_grid = {"model__min_samples_leaf": list(param_values)}
#     411 grid = GridSearchCV(
#     412     pipeline, param_grid, scoring="roc_auc", cv=CV_FOLDS,
#     413     n_jobs=1,            # serial — no data duplication across workers (memory safe)
#     414     pre_dispatch=1,      # don't queue extra fits in memory
#     415 )
# --> 416 grid.fit(X_train_res, y_train_res)
#     418 res = pd.DataFrame(grid.cv_results_)[
#     419     ["param_model__min_samples_leaf", "mean_test_score", "std_test_score"]
#     420 ]
#     422 # Free the fitted grid (n_values x folds forests) to reclaim memory
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\18327\anaconda3\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\18327\anaconda3\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\pipeline.py:473, in Pipeline.fit(self, X, y, **params)
#     471     if self._final_estimator != "passthrough":
#     472         last_step_params = routed_params[self.steps[-1][0]]
# --> 473         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     475 return self
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File c:\Users\18327\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\18327\anaconda3\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\18327\anaconda3\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\18327\anaconda3\Lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)
#    1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)
#    1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# ### Observations:
# Sensitivity analysis on the random forest's min_samples_leaf parameter showed the model is robust across a wide range of values. Cross-validated AUC remained stable (~0.832) for leaf sizes from 5 through 50, degrading only at the extreme of min_samples_leaf = 1 (AUC 0.817), where trees split down to near-singleton leaves and overfit. The selected value of 20 falls comfortably within the stable region, confirming the model is not overly sensitive to this hyperparameter and is likely to generalize consistently.

# %% [markdown]
# ## **8. Failure Analysis**

# %%
# Select three representative misclassified records (by rule, not by hand)
# and print them transposed  (viz.select_failure_records / print_failure_records)
ex1, ex2, ex3 = select_failure_records(results["rf"], X_test, y_test)
print_failure_records(ex1, ex2, ex3)
# Out:
# ========== EX1_false_neg_young_lowrisk ==========
# row index: 136021 | prob_MI: 0.025
#                                   136021
# CHECKUP1                        Within 1
# _TOTINDA                             1.0
# _LCSYQTS                             NaN
# DIFFDRES                              No
# CHCOCNC1                              No
# _INCOMG1           $50,000 to < $100,000
# VETERAN3                              No
# DIFFALON                              No
# _SMOKER3                      Non Smoker
# PREGNANT                              No
# LCSNUMCG                             NaN
# PERSDOC3                             One
# DEAF                                  No
# MARITAL                    Never married
# PNEUVAC4                              No
# CHCKDNY2                              No
# _LCSYSMK                             NaN
# POORHLTH                             NaN
# HAVARTH4                              No
# PHYSHLTH                             NaN
# DIABETE4                     No Diabetes
# CHCCOPD3                              No
# PRIMINS2     State-sponsored health plan
# CVDSTRK3                              No
# DIFFWALK                              No
# _RFHLTH            Good or Better Health
# _AGEG5YR                             1.0
# _MICHD_true                          1.0
# pred                                 0.0
# prob_MI                         0.024873
#
# ========== EX2_false_pos_comorbid ==========
# row index: 324306 | prob_MI: 0.957
#                            324306
# CHECKUP1                 Within 1
# _TOTINDA                      0.0
# _LCSYQTS                     11.0
# DIFFDRES                       No
# CHCOCNC1                       No
# _INCOMG1     $25,000 to < $35,000
# VETERAN3                      Yes
# DIFFALON                      Yes
# _SMOKER3            Former Smoker
# PREGNANT                  Unknown
# LCSNUMCG                     40.0
# PERSDOC3            More than one
# DEAF                           No
# MARITAL                   Married
# PNEUVAC4                      Yes
# CHCKDNY2                      Yes
# _LCSYSMK                     37.0
# POORHLTH                     30.0
# HAVARTH4                      Yes
# PHYSHLTH                     30.0
# DIABETE4                 Diabetes
# CHCCOPD3                      Yes
# PRIMINS2                 Medicare
# CVDSTRK3                      Yes
# DIFFWALK                      Yes
# _RFHLTH       Fair or Poor Health
# _AGEG5YR                      9.0
# _MICHD_true                   0.0
# pred                          1.0
# prob_MI                   0.95683
#
# ========== EX3_borderline_conflicting ==========
# row index: 413841 | prob_MI: 0.5
#                              413841
# CHECKUP1                   Within 1
# _TOTINDA                        1.0
# _LCSYQTS                       63.0
# DIFFDRES                         No
# CHCOCNC1                         No
# _INCOMG1     $100,000 to < $200,000
# VETERAN3                         No
# DIFFALON                         No
# _SMOKER3              Former Smoker
# PREGNANT                    Unknown
# LCSNUMCG                        8.0
# PERSDOC3                        One
# DEAF                             No
# MARITAL                     Married
# PNEUVAC4                        Yes
# CHCKDNY2                         No
# _LCSYSMK                        9.0
# POORHLTH                        NaN
# HAVARTH4                        Yes
# PHYSHLTH                        NaN
# DIABETE4                No Diabetes
# CHCCOPD3                         No
# PRIMINS2                   Medicare
# CVDSTRK3                         No
# DIFFWALK                         No
# _RFHLTH       Good or Better Health
# _AGEG5YR                       13.0
# _MICHD_true                     0.0
# pred                            1.0
# prob_MI                    0.500004
# dist_from_5                0.000004

# %%
# Error rates by age, with the three example records marked
# (viz.plot_failure_by_age)
by_age_display = plot_failure_by_age(results["rf"], X_test, y_test, savepath=os.path.join(VIZ_DIR, "failure_by_age.png"))
# Out:
#     Age  Misses (%)  False Alarms (%)    n
#   18-24         0.5               0.4 5834
#   25-29         0.9               0.9 4794
#   30-34         1.4               1.5 5181
#   35-39         1.0               2.6 5687
#   40-44         1.5               4.2 6207
#   45-49         2.0               7.5 5781
#   50-54         2.1              14.6 6366
#   55-59         2.3              23.7 6797
#   60-64         2.8              31.5 8555
#   65-69         2.8              38.0 9454
#   70-74         2.2              50.7 8999
#   75-79         1.7              57.7 7213
#     80+         1.7              60.9 8033
# Unknown         2.2              28.8 1592

# %% [markdown]
# ### Observations:
# Mapping error rates across age reveals that the model's two failure modes are asymmetric. The false-negative rate (missed MIs) remains low and flat, at roughly 2% across all age groups, confirming that the recall-focused design rarely misses true cases regardless of age. The false-positive rate, by contrast, rises steeply with age, from under 1% among respondents aged 18–24 to over 60% among those 80 and older. This is the base-rate inflation effect made visible: because undersampling trained the model in a balanced world while the population is only ~9% positive, it over-flags older respondents, the majority of whom never had an MI. The three documented failure cases sit exactly where the pattern predicts, Example 1 in the flat low-error young region, and Examples 2 and 3 along the climbing false-alarm curve, confirming they are representative of systematic behavior rather than isolated anomalies.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=88479c56-07bc-4e04-92b4-d8345dc226f4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
